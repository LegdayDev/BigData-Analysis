# %% [markdown]
# ## Matplotlib 학습
#
# ### Matplot.lib
# - Python 의 시각화 라이브러리, 다양한 차트 생성가능
#
# ### Seaborn
# - Matplotlib 확장판

# %%
import pandas as pd
# !pip3 install matplotlib

# %% [markdown]
# ### Mac 에서 한글 깨짐 현상 해결

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import rc

rc('font', family='D2Coding')

plt.rcParams['axes.unicode_minus'] = False

# %%
# 단일차트
plt.plot([1, 2, 3, 4, 5])
plt.show()

# %%
plt.plot(np.random.rand(50))  # 50개의 정수를 랜덤하게 만든다.
plt.show()

# %%
# 다중차트, figure() 사용
fig = plt.figure()
plt1 = fig.add_subplot(2, 2, 1)  # 1번 차트
plt2 = fig.add_subplot(2, 2, 2)  # 2번 차트
plt3 = fig.add_subplot(2, 2, 3)  # 3번 차트
plt4 = fig.add_subplot(2, 2, 4)  # 4번 차트

plt1.plot(np.random.randn(50))
plt2.hist(np.random.randn(100))  # 히스토그램
plt3.scatter(np.arange(30), np.random.randn(30))  # scatter차트 (x축, y축)
plt4.plot(np.random.randn(30), 'violet')  # 색상 추가 가능

plt.show()

# %%
# 다중차트 - 2번째
# figsize 옵션으로 넓이,높이 조정가#
fig, axes = plt.subplots(2, 2, figsize=(14, 6))  # row, column
axes[0][0].plot(np.random.randn(50))
axes[0][1].hist(np.random.randn(100))
axes[1][0].scatter(np.arange(30), np.random.randn(30))
axes[1][1].plot(np.random.randn(30), 'violet')

plt.show()

# %% [markdown]
# ### 차트 스타일 지정 옵션
# - `label` , `style` , `alpha` , `rot` , `xticks` , `yticks` , `xlim` , `ylim` , `color` , `marker` ...

# %%
fig, axes = plt.subplots(2, 3, figsize=(14, 6))
# color = 'k' 는 검정색 , alpha 는 투명도 지정(0.0 ~ 1.0)
axes[0][0].plot(np.random.randn(50), color='c', alpha=0.6)

# bins 는 grouping 갯수
axes[0][1].hist(np.random.randn(100), color='green', bins=10)

# linestyle 은 선 종류 : -- , --, -. :, solid , dashed , dashdot , dotted
axes[0][2].plot(np.random.randn(50), color='r', linestyle='dotted')

# marker : *(별) / ^(삼각형) / o(동그라미)
axes[1][0].scatter(np.arange(30), np.random.randn(30), marker='*')
axes[1][1].plot(np.random.randn(30), 'violet')
axes[1][2].plot(np.random.randn(20), marker="o")

plt.show()

# %%
# cumsum() : cumulative sum 누적합
plt.plot(np.random.randn(50).cumsum(), label='data1')
plt.plot(np.random.randn(50).cumsum(), label='data2')
plt.plot(np.random.randn(50).cumsum(), label='data3')

# legend() : 범례 표시함수
#  'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right' 
#  'center left', 'center right', 'lower center', 'upper center', 'center'
plt.legend(loc='lower left')
plt.show()

# %%
# x,y축 설정
plt.figure(figsize=(18, 5))
plt.plot(np.random.randn(1000))

# x 축을 0, 250, 500, 750, 1000 으로 나눈다.
plt.xticks([0, 250, 500, 750, 1000], labels=['min','25%','median','75%','max']) 

plt.title('Stastics') # 한글에는 문제가 있다.
plt.show()

# %% [markdown]
# ## Pandas 의 DataFrame, Series 를 바로 Matplotlib 과 연계하여 바로 차트를 그릴 수 있다.

# %%
import pandas as pd

df_all = pd.read_excel('./data/df_all.xlsx')
df_all
# Out:
#   국적코드  성별    입국객수    전년동기 국적명
# 0  A01  남성  106320   85815  일본
# 1  A01  여성  191436  125241  일본
# 2  A18  남성  158912  124486  중국
# 3  A18  여성  232943  163466  중국
# 4  A01  남성   92556   75992  일본
# 5  A01  여성  163737  115397  일본
# 6  A18  남성  155540  129908  중국
# 7  A18  여성  249023  191236  중국

# %%
df_all.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Seaborn 라이브러리
# - Matplotlib 서드파티 라이브러리
# - Matplotlib 보다 훨씬 이쁘게 차트를 생성할 수 있음

# %% [markdown]
# #### seaborn 라이브러리 설치
# `!pip3 install seaborn`

# %%
# !pip3 install seaborn

# %%
import matplotlib.pyplot as plt1
import pandas as pd
import seaborn as sns

# %% [markdown]
# #### Seaborn 특징
# > 1. 기본적으로 샘플 데이터도 제공
# > 2. 손쉽게 샘플 차트를 생성 가능

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
## 내장 데이터셋 목록 확인
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
irisData = sns.load_dataset('iris') # 불꽃 샘플 데이터
irisData
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flights = sns.load_dataset('flights') # 1949 ~ 1960년 월별 비행기 승객수
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.set_style('darkgrid')
sns.set_color_codes('')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 sns.set_style('darkgrid')
# ----> 2 sns.set_color_codes('')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/palettes.py:837, in set_color_codes(palette)
#     835 else:
#     836     err = f"Cannot set colors with palette '{palette}'"
# --> 837     raise ValueError(err)
#     839 for code, color in zip("bgrmyck", colors):
#     840     rgb = mpl.colors.colorConverter.to_rgb(color)
#
# ValueError: Cannot set colors with palette ''

# %%
sns.barplot(data=flights, x='year', y='passengers', color='b')
plt.show()

# %%
sns.boxplot(data=flights, x='year', y='passengers')
plt.show()
